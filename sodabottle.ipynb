# %% [markdown]
# # Soda Bottle Identification

# %% [markdown]
# We're going to use convolutional neural networks (CNNs) to allow the computer to recognize over 8 different soda bottle types as part of the Soda Bottle Classification Challenge. This notebook uses concepts learned in the fastai course, specifically:
# 1. How to find the learning rate
# 2. Use of precomputed activations
# 3. Application of data augmentation
# 4. Test-time Augmentation for increasing accuracy

# %% [markdown]
# ## Library Imports

# %% [markdown]
# There are 5769 images of soda bottles in 8 different classes

# %%
# Put these at the top of every notebook, to get automatic reloading and inline plotting
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# Here we import the libraries we need. We'll learn about what each does during the course.

# %%
# This file contains all the main external libs we'll use
from fastai import *
from fastai.vision import *
import torch

# %%
# from fastai.vision.transform import *
# from fastai.conv_learner import *
# from fastai.model import *
# from fastai.dataset import *
# from fastai.sgdr import *
# from fastai.plots import *

# %% [markdown]
# `PATH` is the path to your data - if you use the recommended setup approaches from the lesson, you won't need to change this. `sz` is the size that the images will be resized to in order to ensure that the training runs quickly. We'll be talking about this parameter a lot during the course. Leave it at `224` for now.

# %%
PATH = "data/sodabottle/"
sz=224

# %% [markdown]
# It's important that you have a working NVidia GPU set up. The programming framework used to behind the scenes to work with NVidia GPUs is called CUDA. Therefore, you need to ensure the following line returns `True` before you proceed. If you have problems with this, please check the FAQ and ask for help on [the forums](http://forums.fast.ai).

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# In addition, NVidia provides special accelerated functions for deep learning in a package called CuDNN. Although not strictly necessary, it will improve training performance significantly, and is included by default in all supported fastai configurations. Therefore, if the following does not return `True`, you may want to look into why.

# %%
torch.backends.cudnn.enabled
# Out:
# True

# %% [markdown]
# ## First look at Soda Bottle Pictures

# %% [markdown]
# Our library will assume that you have *train* directory. A *train.csv* file contains the label of each image. A set of validation indices are chosen here.

# %%
os.listdir(PATH)
# Out:
# ['P.Orig',
#  'P.diet',
#  'M.Beer',
#  'P.Cherry',
#  'P.Zero',
#  'train.csv',
#  'meta.json',
#  'MD.Orig',
#  'labels.csv',
#  'MD.Diet',
#  'P.Rsugar']

# %%
label_csv = f'{PATH}train.csv'
n = len(list(open(label_csv))) - 1
# val_idxs = get_cv_idxs(n)

# %%
label_df = pd.read_csv(label_csv)

# %%
label_df.head()
# Out:
#      label              name
# 0  MD.Diet  MD.Diet/5653.jpg
# 1  MD.Diet  MD.Diet/5647.jpg
# 2  MD.Diet  MD.Diet/5690.jpg
# 3  MD.Diet  MD.Diet/5684.jpg
# 4  MD.Diet  MD.Diet/5479.jpg

# %%
label_df.columns
# Out:
# Index(['label', 'name'], dtype='object')

# %%
val_idxs = label_df[['name']]
val_idxs
# Out:
#                             name
# 0               MD.Diet/5653.jpg
# 1               MD.Diet/5647.jpg
# 2               MD.Diet/5690.jpg
# 3               MD.Diet/5684.jpg
# 4               MD.Diet/5479.jpg
# 5               MD.Diet/1810.jpg
# 6               MD.Diet/1804.jpg
# 7               MD.Diet/5492.jpg
# 8               MD.Diet/5486.jpg
# 9               MD.Diet/1838.jpg
# 10              MD.Diet/5519.jpg
# 11              MD.Diet/5525.jpg
# 12              MD.Diet/1743.jpg
# 13              MD.Diet/1757.jpg
# 14    MD.Diet/2668_corrected.jpg
# 15              MD.Diet/5531.jpg
# 16              MD.Diet/1964.jpg
# 17              MD.Diet/3815.jpg
# 18              MD.Diet/3801.jpg
# 19              MD.Diet/1970.jpg
# 20              MD.Diet/1780.jpg
# 21              MD.Diet/1958.jpg
# 22              MD.Diet/3829.jpg
# 23              MD.Diet/1794.jpg
# 24              MD.Diet/2074.jpg
# 25              MD.Diet/2060.jpg
# 26              MD.Diet/2048.jpg
# 27              MD.Diet/5727.jpg
# 28              MD.Diet/5733.jpg
# 29              MD.Diet/5732.jpg
# ...                          ...
# 6585                    6550.jpg
# 6586                    6544.jpg
# 6587                    2939.jpg
# 6588                    6587.jpg
# 6589                    6586.jpg
# 6590                    2938.jpg
# 6591                    6592.jpg
# 6592                    6545.jpg
# 6593                    6551.jpg
# 6594                    6579.jpg
# 6595                    4193.jpg
# 6596                    4187.jpg
# 6597                    3159.jpg
# 6598                    4150.jpg
# 6599                    4144.jpg
# 6600                    3165.jpg
# 6601                    4178.jpg
# 6602                    3171.jpg
# 6603                    6633.jpg
# 6604                    6627.jpg
# 6605                    3039.jpg
# 6606                    3011.jpg
# 6607                    3005.jpg
# 6608                    4226.jpg
# 6609                    6431.jpg
# 6610                    6425.jpg
# 6611                    4232.jpg
# 6612                    3213.jpg
# 6613                    3207.jpg
# 6614                    6419.jpg
#
# [6615 rows x 1 columns]

# %%
label_df.pivot_table(index='label', aggfunc=len).sort_values('name', ascending=False)
# Out:
#           name
# label
# P.diet     850
# MD.Orig    844
# M.Beer     840
# MD.Diet    839
# P.Rsugar   825
# P.Zero     824
# P.Orig     800
# P.Cherry   793

# %% [markdown]
# Here is how the raw data looks like

# %% [markdown]
# ## Our first model: quick start

# %% [markdown]
# We're going to use a <b>pre-trained</b> model, that is, a model created by some one else to solve a different problem. Instead of building a model from scratch to solve a similar problem, we'll use a model trained on ImageNet (1.2 million images and 1000 classes) as a starting point. The model is a Convolutional Neural Network (CNN), a type of Neural Network that builds state-of-the-art models for computer vision. We'll be learning all about CNNs during this course.
#
# We will be using the <b>resnext101</b> model. resnext101 is a version of the model built by Facebook Research. Here is more info on [resnet models](https://github.com/KaimingHe/deep-residual-networks).

# %%
# Uncomment the below if you need to reset your precomputed activations
# shutil.rmtree(f'{PATH}tmp', ignore_errors=True)

# %%
arch = models.xresnet101
sz = 224
bs = 32

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder("data/sodabottle", train='.', valid_pct=0.2,
                                  ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
from fastai.metrics import error_rate # 1 - accuracy
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 00:51 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.680284</td>
#       <td>0.244596</td>
#       <td>0.085412</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses, idxs = interp.top_losses()
len(data.valid_ds) == len(losses) == len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(20,12))

# %%
interp.plot_confusion_matrix(figsize=(18,18), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('P.Cherry', 'P.Orig', 35),
#  ('MD.Orig', 'MD.Diet', 18),
#  ('P.Orig', 'P.Cherry', 16),
#  ('P.Zero', 'P.diet', 10),
#  ('MD.Diet', 'MD.Orig', 7),
#  ('P.diet', 'P.Zero', 6),
#  ('P.Cherry', 'P.Rsugar', 5),
#  ('P.Rsugar', 'P.Cherry', 4),
#  ('M.Beer', 'P.diet', 2),
#  ('P.Rsugar', 'P.diet', 2),
#  ('P.Zero', 'P.Orig', 2)]

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(3)
# Out:
# Total time: 03:40 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.023060</td>
#       <td>0.041785</td>
#       <td>0.012094</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.035391</td>
#       <td>0.056651</td>
#       <td>0.011338</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.016882</td>
#       <td>0.009418</td>
#       <td>0.001512</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp.plot_top_losses(9, figsize=(20,12))

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(1, 1e-3)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='82', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-115-d7c6ddf997a7> in <module>
#       1 learn.unfreeze()
# ----> 2 learn.fit_one_cycle(1, 1e-3)
#
# ~/Documents/projects/sodabottles/fastai/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, final_div, wd, callbacks, tot_epochs, start_epoch)
#      20     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor, pct_start=pct_start,
#      21                                        final_div=final_div, tot_epochs=tot_epochs, start_epoch=start_epoch))
# ---> 22     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      23
#      24 def lr_find(learn:Learner, start_lr:Floats=1e-7, end_lr:Floats=10, num_it:int=100, stop_div:bool=True, wd:float=None):
#
# ~/Documents/projects/sodabottles/fastai/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     177         if defaults.extra_callbacks is not None: callbacks += defaults.extra_callbacks
#     178         fit(epochs, self.model, self.loss_func, opt=self.opt, data=self.data, metrics=self.metrics,
# --> 179             callbacks=self.callbacks+callbacks)
#     180
#     181     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/Documents/projects/sodabottles/fastai/fastai/utils/mem.py in wrapper(*args, **kwargs)
#      96                 if "device-side assert triggered" in str(e):
#      97                     warn("""When 'device-side assert triggered' error happens, it's not possible to recover and you must restart the kernel to continue. Use os.environ['CUDA_LAUNCH_BLOCKING']="1" before restarting to debug""")
# ---> 98                 raise type(val).with_traceback(tb) from None
#      99             else: raise # re-raises the exact last exception
#     100     return wrapper
#
# ~/Documents/projects/sodabottles/fastai/fastai/utils/mem.py in wrapper(*args, **kwargs)
#      87
#      88         try:
# ---> 89             return func(*args, **kwargs)
#      90         except Exception as e:
#      91             if ("CUDA out of memory" in str(e) or
#
# ~/Documents/projects/sodabottles/fastai/fastai/basic_train.py in fit(***failed resolving arguments***)
#      88             for xb,yb in progress_bar(data.train_dl, parent=pbar):
#      89                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# ---> 90                 loss = loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      91                 if cb_handler.on_batch_end(loss): break
#      92
#
# ~/Documents/projects/sodabottles/fastai/fastai/basic_train.py in loss_batch(***failed resolving arguments***)
#      20     if not is_listy(xb): xb = [xb]
#      21     if not is_listy(yb): yb = [yb]
# ---> 22     out = model(*xb)
#      23     out = cb_handler.on_loss_begin(out)
#      24
#
# ~/Envs/venv/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(***failed resolving arguments***)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/Envs/venv/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(***failed resolving arguments***)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/Envs/venv/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(***failed resolving arguments***)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/Envs/venv/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(***failed resolving arguments***)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/Envs/venv/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(***failed resolving arguments***)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/Envs/venv/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(***failed resolving arguments***)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/Envs/venv/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(***failed resolving arguments***)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/Envs/venv/lib/python3.6/site-packages/torchvision/models/resnet.py in forward(***failed resolving arguments***)
#      39         residual = x
#      40
# ---> 41         out = self.conv1(x)
#      42         out = self.bn1(out)
#      43         out = self.relu(out)
#
# ~/Envs/venv/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(***failed resolving arguments***)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/Envs/venv/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(***failed resolving arguments***)
#     318     def forward(self, input):
#     319         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 320                         self.padding, self.dilation, self.groups)
#     321
#     322
#
# RuntimeError: CUDA out of memory. Tried to allocate 6.12 MiB (GPU 0; 3.95 GiB total capacity; 2.60 GiB already allocated; 19.44 MiB free; 30.59 MiB cached)

# %%
#tfms = tfms_from_model(arch, sz, aug_tfms=transforms_side_on, max_zoom=1.1)
# tfms = get_transforms(do_flip=False
# data = ImageClassifierData.from_csv(PATH, 'train', f'{PATH}train.csv', val_idxs=val_idxs, tfms = tfms, bs = bs)

# %%
fn = PATH + data.trn_ds.fnames[0];fn
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-3f001d070496> in <module>
# ----> 1 fn = PATH + data.trn_ds.fnames[0];fn
#
# ~/Documents/projects/sodabottles/fastai/fastai/basic_data.py in __getattr__(self, k)
#     120         return cls(*dls, path=path, device=device, dl_tfms=dl_tfms, collate_fn=collate_fn, no_check=no_check)
#     121
# --> 122     def __getattr__(self,k:int)->Any: return getattr(self.train_dl, k)
#     123     def __setstate__(self,data:Any): self.__dict__.update(data)
#     124
#
# ~/Documents/projects/sodabottles/fastai/fastai/basic_data.py in __getattr__(self, k)
#      36
#      37     def __len__(self)->int: return len(self.dl)
# ---> 38     def __getattr__(self,k:str)->Any: return getattr(self.dl, k)
#      39     def __setstate__(self,data:Any): self.__dict__.update(data)
#      40
#
# ~/Documents/projects/sodabottles/fastai/fastai/basic_data.py in DataLoader___getattr__(dl, k)
#      18 torch.utils.data.DataLoader.__init__ = intercept_args
#      19
# ---> 20 def DataLoader___getattr__(dl, k:str)->Any: return getattr(dl.dataset, k)
#      21 DataLoader.__getattr__ = DataLoader___getattr__
#      22
#
# ~/Documents/projects/sodabottles/fastai/fastai/data_block.py in __getattr__(self, k)
#     594         res = getattr(y, k, None)
#     595         if res is not None: return res
# --> 596         raise AttributeError(k)
#     597
#     598     def __setstate__(self,data:Any): self.__dict__.update(data)
#
# AttributeError: trn_ds

# %%
img = PIL.Image.open(fn); img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7F1854D30198>

# %%
img.size
# Out:
# (640, 480)

# %%
len(data.trn_ds)
# Out:
# 5296

# %%
len(data.classes), data.classes[:8]
# Out:
# (8,
#  ['M.Beer',
#   'MD.Diet',
#   'MD.Orig',
#   'P.Cherry',
#   'P.Orig',
#   'P.Rsugar',
#   'P.Zero',
#   'P.diet'])

# %% [markdown]
# Data is passed without any augmentation

# %%
def get_data(sz, bs):
    #tfms = tfms_from_model(arch, sz, aug_tfms = transforms_side_on, max_zoom=1.1)
    tfms = tfms_from_model(arch, sz)
    data = ImageClassifierData.from_csv(PATH, 'train', f'{PATH}train.csv', val_idxs=val_idxs, 
                                       tfms = tfms, bs= bs)
    return data if sz > 300 else data.resize(340, 'tmp')

# %%
data = get_data(sz, bs)
# Out:
# HBox(children=(IntProgress(value=0, max=6), HTML(value='')))

# %%
learn = ConvLearner.pretrained(arch, data, precompute = True, ps=0.5)

# %%
lrf=learn.lr_find()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#  73%|███████▎  | 122/166 [00:02<00:00, 56.89it/s, loss=6.44]

# %%
learn.sched.plot_lr()

# %% [markdown]
# Learning Rate of 0.03 is chosen as at that rate, the loss is still falling rapidly.

# %%
learn.sched.plot()

# %%
learn.fit(0.03, 4)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=4), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.610392   0.25476    0.917611
#     1      0.373792   0.203702   0.927438
#     2      0.327016   0.128842   0.962963
#     3      0.26389    0.125802   0.965986
# [array([0.1258]), 0.9659863945578231]

# %%
learn.precompute = False

# %%
def get_data(sz, bs):
    tfms = tfms_from_model(arch, sz, aug_tfms = transforms_side_on, max_zoom=1.1)
    #tfms = tfms_from_model(arch, sz)
    data = ImageClassifierData.from_csv(PATH, 'train', f'{PATH}train.csv', val_idxs=val_idxs, 
                                       tfms = tfms, bs= bs)
    return data if sz > 300 else data.resize(340, 'tmp')

# %%
data = get_data(sz, bs)
# Out:
# HBox(children=(IntProgress(value=0, max=6), HTML(value='')))

# %%
learn.fit(0.03, 2, cycle_len=1)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=2), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.290858   0.105295   0.969766
#     1      0.249638   0.107908   0.972789
# [array([0.10791]), 0.9727891156462585]

# %%
learn.unfreeze()

# %%
lr=np.array([0.0003,0.0003,0.03])

# %%
learn.fit(lr, 3, cycle_len=1, cycle_mult=2)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.208073   0.09548    0.976568
#     1      0.133651   0.066203   0.984883
#     2      0.088515   0.062513   0.98715
#     3      0.099246   0.068679   0.981859
#     4      0.058039   0.053789   0.989418
#     5      0.039598   0.055181   0.98715
#     6      0.046372   0.051528   0.990174
# [array([0.05153]), 0.9901738473167044]

# %%
learn.sched.plot_lr()

# %%
learn.save('224_pre')

# %%
learn.load('224_pre')

# %%
from sklearn import metrics

# %%
log_preds,y = learn.TTA()

# %%
probs = np.mean(np.exp(log_preds),0)

# %%
accuracy_np(probs, y)
# Out:
# 0.9894179894179894

# %%
preds = np.argmax(probs, axis=1)
probs = probs[:,1]

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y, preds)

# %%
plot_confusion_matrix(cm, data.classes)
# Out:
# [[163   0   0   0   0   0   0   1]
#  [  0 161   1   0   0   0   0   0]
#  [  0   1 167   0   0   0   0   1]
#  [  1   0   0 151   1   0   0   0]
#  [  0   0   0   1 149   0   0   0]
#  [  0   0   0   0   3 168   0   0]
#  [  0   0   0   0   0   2 180   0]
#  [  0   0   1   0   0   0   1 170]]

# %%
def rand_by_mask(mask): return np.random.choice(np.where(mask)[0], 4, replace=False)
def rand_by_correct(is_correct): return rand_by_mask((preds == data.val_y)==is_correct)
def most_by_mask(mask, mult):
    idxs = np.where(mask)[0]
    return idxs[np.argsort(mult * probs[idxs])[:4]]

def most_by_correct(y, is_correct): 
    mult = -1 if (y==1)==is_correct else 1
    return most_by_mask(((preds == data.val_y)==is_correct) & (data.val_y == y), mult)

# %%
def plot_val_with_title(idxs, title):
    imgs = np.stack([data.val_ds[x][0] for x in idxs])
    title_probs = [probs[x] for x in idxs]
    print(title)
    return plots(data.val_ds.denorm(imgs), rows=1, titles=title_probs)

# %%
plot_val_with_title(most_by_correct(0, False), "Most incorrect soda")
# Out:
# Most incorrect soda

# %%
plot_val_with_title(most_by_correct(1, True), "Most correct soda")
# Out:
# Most correct soda

# %%
plot_val_with_title(rand_by_correct(False), "Incorrectly classified")
# Out:
# Incorrectly classified

# %%
plot_val_with_title(rand_by_correct(True), "Correctly classified")
# Out:
# Correctly classified
